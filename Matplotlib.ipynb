# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.2

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 6])
ypoints = np.array([2, 250])

plt.plot(xpoints, ypoints, 'D')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6, 1, 9])
ypoints = np.array([0, 45, 125, 220])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,4,7,9])

plt.plot(ypoints, marker = 'H')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,4,5,6,9])

plt.plot(ypoints, marker = 'p', markersize = '20')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'Khaki', mfc = 'Orchid')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10, 20, 30, 40])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, marker = 'o', ms = 20, mec = 'Khaki', mfc = 'Orchid', ls = '-.')
plt.plot(ypoints, marker = 'H', ms = 10, mec = 'Gold', mfc = 'Magenta', ls = ':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()
# c = 'hotpink'
# c = '#4CAF50'

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5', c = 'Lime')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([1,4,8,2,9,6])
y = ([5,45,20,35,15,30])

font1={'family':'sans-serif','color':'red','size':20}
font2={'family':'cursive','color':'orange','size':15}

plt.title("Sports Watch Data", font1)
plt.xlabel("Average Pulse", font2)
plt.ylabel("Calorie Burn", font2)

plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([1,4,8,2,9,6])
y = ([5,45,20,35,15,30])

font1={'family':'sans-serif','color':'red','size':20}
font2={'family':'cursive','color':'orange','size':15}

plt.title("Sports Watch Data", font1, loc = 'left')
plt.xlabel("Average Pulse", font2)
plt.ylabel("Calorie Burn", font2)

plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([1,4,8,2,9,6])
y = ([5,45,20,35,15,30])

font1={'family':'sans-serif','color':'red','size':20}
font2={'family':'cursive','color':'orange','size':15}

plt.title("Sports Watch Data", font1)
plt.xlabel("Average Pulse", font2)
plt.ylabel("Calorie Burn", font2)

plt.plot(x,y)

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([1,4,8,2,9,6])
y = ([5,45,20,35,15,30])

font1={'family':'sans-serif','color':'red','size':20}
font2={'family':'cursive','color':'orange','size':15}

plt.title("Sports Watch Data", font1)
plt.xlabel("Average Pulse", font2)
plt.ylabel("Calorie Burn", font2)

plt.plot(x,y)

plt.grid(axis = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([1,4,8,2,9,6])
y = ([5,45,20,35,15,30])

font1={'family':'sans-serif','color':'red','size':20}
font2={'family':'cursive','color':'orange','size':15}

plt.title("Sports Watch Data", font1)
plt.xlabel("Average Pulse", font2)
plt.ylabel("Calorie Burn", font2)

plt.plot(x,y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot 1
x = np.array([0,1,2,3])
y = np.array([7,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)

#Plot 2
x = np.array([4,5,6,7])
y = np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

# # #Plot 3:
# x = np.array([0, 1, 2, 3])
# y = np.array([3, 6, 9, 12])

# plt.subplot(2, 1, 3)
# plt.plot(x,y)

# # #Plot 4:
# x = np.array([0, 1, 2, 3])
# y = np.array([4, 8, 13, 16])

# plt.subplot(2, 1, 4)
# plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot 1:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("Fig 1")

# Plot 2:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title("Fig 2")

# Plot 3:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.title("Fig 3")

# PLot 4:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title("Fig 4")

# Plot 5:
x = np.array([0, 1, 2])
y = np.array([3, 8, 1])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title("Fig 5")

# Plot 6:
x = np.array([0, 1, 2])
y = np.array([10, 20, 30])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title("Fig 6")

plt.suptitle("Plots")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Avg of first 15:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

# Avg of second 15:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'Chocolate')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'Coral') # color = '#88c999'

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, up to 100, which is a yellow color.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, c = colors,cmap = 'Reds')
plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x,y, s=sizes, alpha=0.5)
plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x =  np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='tab10')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, color = "green", height = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,15,6])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,15,6])
mylabels = ['A','B','C','D']

plt.pie(x, labels = mylabels,startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.2,0,0,0]

plt.pie(x, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.2,0,0,0]
mycolors = ["DarkSalmon","#65b2d2","Ivory","Teal"]

plt.pie(x, labels = mylabels, explode = myexplode, shadow = True,colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.2,0,0,0]
mycolors = ["DarkSalmon","#65b2d2","#FF00FF","Teal"]

plt.pie(x, labels = mylabels, explode = myexplode, shadow = True,colors = mycolors)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,30,40])
mylabels = ['A','B','C','D']
myexplode = [0.2,0,0,0]
mycolors = ["DarkSalmon","#65b2d2","#FF00FF","Teal"]

plt.pie(x, labels = mylabels, explode = myexplode, shadow = True,colors = mycolors)
plt.legend(title = "Letters")
plt.show()
